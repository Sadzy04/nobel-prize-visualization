# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np

# Start coding here!
dataf = pd.read_csv('data/nobel.csv')
sns.set_context('notebook')
#sns.catplot(data = dataf, x = 'birth_country', kind = 'count')
top_gender = 'Male'
top_country = 'United States of America'

# %%
dataf.head(5)
# Out:
#    year    category  ... death_city death_country
# 0  1901   Chemistry  ...     Berlin       Germany
# 1  1901  Literature  ...   Châtenay        France
# 2  1901    Medicine  ...    Marburg       Germany
# 3  1901       Peace  ...     Heiden   Switzerland
# 4  1901       Peace  ...      Paris        France
#
# [5 rows x 18 columns]

# %%
datademo = dataf[dataf['sex'] == 'Female']

ans = datademo[datademo['year'] == 1903]
first_woman_name = 'Marie Curie, née Sklodowska'
first_woman_category = 'Physics'

# %%
ds = dataf.groupby('full_name').count()
re = ds[ds['year'] > 1]
repeat = (re.index)
repeat_list = ['Comité international de la Croix Rouge (International Committee of the Red Cross)', 'Frederick Sanger', 'John Bardeen', 'Linus Carl Pauling', 'Marie Curie, née Sklodowska', 'Office of the United Nations High Commissioner for Refugees (UNHCR)']
print(repeat_list)
# Out:
# ['Comité international de la Croix Rouge (International Committee of the Red Cross)', 'Frederick Sanger', 'John Bardeen', 'Linus Carl Pauling', 'Marie Curie, née Sklodowska', 'Office of the United Nations High Commissioner for Refugees (UNHCR)']

# %%
dataf['us'] = dataf['birth_country'] == 'United States of America'
dataf['decade'] = (np.floor(dataf['year']/10) * 10).astype(int)
pop = dataf.groupby('decade', as_index = False)['us'].mean()
max_decade_usa = pop.loc[pop['us'].idxmax(), 'decade']

# %%
dataf['f_winners'] = dataf['sex'] == 'Female'
# Assuming you've already created a 'decade' column and the 'f_winners' column.
proportions = dataf.groupby(['decade', 'category'], as_index=False)['f_winners'].mean()
max_female_index = proportions['f_winners'].idxmax()
max_female_row = proportions.loc[max_female_index]
max_female_dict = {
    max_female_row['decade'] : 
    max_female_row['category']
}

print(max_female_dict)
# Out:
# {2020: 'Literature'}
